# %% [markdown]
# # Product Recommendation

# %%
import numpy as np
import pandas as pd
from customized import preprocess
from customized import metrics
from customized import product_recommendation
from striatum import MAB
from striatum.storage.action import Action
from neural_exploration import neuralucb_main
import importlib
importlib.reload(product_recommendation)
# Out:
# <module 'customized.product_recommendation' from '/home/Oring-AI/jambo/Livestream-Ecommerce-Recommender-System/customized/product_recommendation.py'>

# %% [markdown]
# ## Context Comparison

# %% [markdown]
# ### without class weights

# %%
# experiments = ['static', 'temporal']
# mylabels = ['Static Context', 'Temporal Context']
experiments = ['basket', 'streamer']
mylabels = ['Customer-Product Context', 'Customer-Streamer Context']
fig_name = 'lers_temporal_big'
regrets_context, hr_context, all_reward_pivot, cust_id, reward_cust_id, reward_prod_id, topk_context = product_recommendation.main(experiments, mylabels, fig_name, 2602, 1023)
# Out:
# [Test] change Double to Float
# Step [8/8], Reconstructed Loss: 0.0230
# product feature: (1023, 32)
# streamer feature: (1023, 23)
# small streamer-product: (1023, 55)
# 100% (2602 of 2602) |####################| Elapsed Time: 0:00:07 Time:  0:00:07
# Recommend Ratio: 0.12 %
# Accuracy: 97.69 %
# Correct: 2542
# Regret: 0.0231
# Early Stop times: 44
# Current seed: 2744921026256110948
# 100% (2602 of 2602) |####################| Elapsed Time: 0:00:07 Time:  0:00:07
# Recommend Ratio: 0.12 %
# Accuracy: 98.04 %
# Correct: 2551
# Regret: 0.0196
# Early Stop times: 37
# Current seed: 12390857788147745413
# basket's regret: 0.0231
# streamer's regret: 0.0196
# basket's hit ratio: 16.57 %
# streamer's hit ratio: 14.31 %

# %% [markdown]
# ### with class weights

# %%
experiments = ['basket', 'streamer']
mylabels = ['Customer-Product Context', 'Customer-Streamer Context']
fig_name = 'lers_temporal_big_weights'
_, _, _, _, _, _, _ = product_recommendation.main(experiments, mylabels, fig_name, 2602, 1023, class_weight = True)
# Out:
# [Test] change Double to Float
# Step [8/8], Reconstructed Loss: 0.0230
# product feature: (1023, 32)
# streamer feature: (1023, 23)
# small streamer-product: (1023, 55)
# total: 2661846, pos: 12265, neg: 2649581
# Weight for class 0: 0.50
# Weight for class 1: 108.51
# 100% (2602 of 2602) |####################| Elapsed Time: 0:00:06 Time:  0:00:06
# Recommend Ratio: 99.27 %
# Accuracy: 3.65 %
# Correct: 95
# Regret: 0.9635
# Early Stop times: 35
# Current seed: 1065035862014606645
# 100% (2602 of 2602) |####################| Elapsed Time: 0:00:07 Time:  0:00:07
# Recommend Ratio: 99.00 %
# Accuracy: 3.27 %
# Correct: 85
# Regret: 0.9673
# Early Stop times: 33
# Current seed: 10140428808328324231
# basket's regret: 0.9635
# streamer's regret: 0.9673
# basket's hit ratio: 22.41 %
# streamer's hit ratio: 19.93 %

# %% [markdown]
# ## Uncertainty Structure

# %% [markdown]
# ### without class weights

# %%
experiments = ['aenn', 'vaenn', 'aebnn', 'vaebnn']
mylabels = ['Without Uncetainty', 'Context Uncertainty', 'Recommendation Uncertainty', 'Both Uncertainties']
fig_name = 'lers_structure_big'
regrets_structure, hr_structure, _, _, _, _, topk_structure = product_recommendation.main(experiments, mylabels, fig_name, 2602, 1023)
# Out:
# [Test] change Double to Float
# Step [8/8], Reconstructed Loss: 0.0230
# product feature: (1023, 32)
# streamer feature: (1023, 23)
# small streamer-product: (1023, 55)
# 100% (2602 of 2602) |####################| Elapsed Time: 0:00:06 Time:  0:00:06
# Recommend Ratio: 0.15 %
# Accuracy: 97.43 %
# Correct: 2535
# Regret: 0.0257
# Early Stop times: 35
# 100% (2602 of 2602) |####################| Elapsed Time: 0:00:06 Time:  0:00:06
# Recommend Ratio: 0.15 %
# Accuracy: 98.42 %
# Correct: 2561
# Regret: 0.0158
# Early Stop times: 47
# 100% (2602 of 2602) |####################| Elapsed Time: 0:00:30 Time:  0:00:30
# Recommend Ratio: 100.00 %
# Accuracy: 0.15 %
# Correct: 4
# Regret: 0.9985
# Early Stop times: 41
# 100% (2602 of 2602) |####################| Elapsed Time: 0:00:31 Time:  0:00:31
# Recommend Ratio: 100.00 %
# Accuracy: 0.42 %
# Correct: 11
# Regret: 0.9958
# Early Stop times: 40
# aenn's regret: 0.0257
# vaenn's regret: 0.0158
# aebnn's regret: 0.9985
# vaebnn's regret: 0.9958
# aenn's hit ratio: 16.44 %
# vaenn's hit ratio: 14.2 %
# aebnn's hit ratio: 3.37 %
# vaebnn's hit ratio: 4.78 %

# %% [markdown]
# ### with class weights

# %%
experiments = ['aenn', 'vaenn', 'aebnn', 'vaebnn']
mylabels = ['Without Uncetainty', 'Context Uncertainty', 'Recommendation Uncertainty', 'Both Uncertainties']
fig_name = 'lers_structure_big_weights'
regrets_structure_w, hr_structure_w, _, _, _, _, topk_structure_w = product_recommendation.main(experiments, mylabels, fig_name, 2602, 1023, class_weight = True)
# Out:
# [Test] change Double to Float
# Step [8/8], Reconstructed Loss: 0.0230
# product feature: (1023, 32)
# streamer feature: (1023, 23)
# small streamer-product: (1023, 55)
# total: 2661846, pos: 12265, neg: 2649581
# Weight for class 0: 0.50
# Weight for class 1: 108.51
# 100% (2602 of 2602) |####################| Elapsed Time: 0:00:06 Time:  0:00:06
# Recommend Ratio: 99.77 %
# Accuracy: 2.77 %
# Correct: 72
# Regret: 0.9723
# Early Stop times: 39
# 100% (2602 of 2602) |####################| Elapsed Time: 0:00:08 Time:  0:00:08
# Recommend Ratio: 98.27 %
# Accuracy: 3.57 %
# Correct: 93
# Regret: 0.9643
# Early Stop times: 35
# 100% (2602 of 2602) |####################| Elapsed Time: 0:00:32 Time:  0:00:32
# Recommend Ratio: 100.00 %
# Accuracy: 0.15 %
# Correct: 4
# Regret: 0.9985
# Early Stop times: 40
# 100% (2602 of 2602) |####################| Elapsed Time: 0:00:31 Time:  0:00:31
# Recommend Ratio: 100.00 %
# Accuracy: 0.42 %
# Correct: 11
# Regret: 0.9958
# Early Stop times: 46
# aenn's regret: 0.9723
# vaenn's regret: 0.9643
# aebnn's regret: 0.9985
# vaebnn's regret: 0.9958
# aenn's hit ratio: 21.68 %
# vaenn's hit ratio: 18.04 %
# aebnn's hit ratio: 3.38 %
# vaebnn's hit ratio: 4.75 %

# %% [markdown]
# # MAB

# %%
import importlib
importlib.reload(MAB)
def main(num, full_context, context_id, rewards, reward_prod_id, lers_regret, lers_hr): # 2602人, 815dim
    
    actions = []
    for prod_id in reward_prod_id:
        action = Action(int(prod_id))
        actions.append(action)
    user_features = pd.DataFrame(np.array(full_context), index=context_id)
    all_rewards_df = pd.melt(rewards, ignore_index=False, var_name='商品id', value_name='reward')\
                    .loc[context_id].reset_index()
    print(f"user features: {user_features.shape}, reward targets: {rewards.shape}")
    
    experiment_bandit = ['aenn','vaenn','aebnn','vaebnn','UCB1', 'LinUCB', 'Exp3', 'NeuralUCB','random']
    mab_bandit = ['random', 'UCB1', 'LinUCB', 'Exp3']
    predict_id = {}
    rec_id = {}
    regret = {}
    coverage = {} 
    hr = {}
    topk = {}
    mylabels = ['LERS (Without Uncertainty)','LERS (Context Uncertainty)','LERS (Recommendation Uncertainty)', 'LERS (Both Uncertainties)',\
               'UCB1', 'LinUCB', 'Exp3', 'NeuralUCB', 'Random']

    for bandit in experiment_bandit:   
        print("-----")
        print(bandit)
        if bandit in mab_bandit:      
            policy = MAB.policy_generation(bandit, actions)
            seq_error, rec_id[bandit], predict_id[bandit] = MAB.policy_evaluation(policy, bandit, num, user_features, rewards, actions, len(actions))
            regret[bandit] = MAB.regret_calculation(seq_error)
            if bandit != 'random':
                hr[bandit], k_list, topk[bandit] = metrics.cal_hit_ratio_mab(all_rewards_df, predict_id[bandit], min_val=10, max_val=55, step=5)

        elif bandit == 'NeuralUCB':
            neuralUCB_regret, neuralUCB_reward_df, predict_id[bandit] = neuralucb_main.myNeuralUCB(user_features, rewards, p=0.2, hidden_size=32, epochs=10, use_cuda=False, seed=np.random.seed(2022))
            regret['NeuralUCB'] = neuralUCB_regret
            hr[bandit], _, topk[bandit] = metrics.cal_hit_ratio_neuralucb(all_rewards_df, predict_id[bandit], min_val=10, max_val=55, step=5)
        else:
            regret[bandit] = lers_regret[bandit]  
            hr[bandit] = lers_hr[bandit]
    
        
    # plot regret
    metrics.plot_regret(regret, mylabels, 'all_big', rounds=num)
    # plot hit ratio
    metrics.plot_hit_ratio(hr, k_list, mylabels, 'all_big')
    
    return regret, hr, predict_id, topk

# %% [markdown]
# ## blurry_context

# %%
mab_context = np.load('data/mab_context.npy')
mab_context, mab_context_id, _ = preprocess.trim_cust_for_context_sort(mab_context, cust_id, reward_cust_id)
regret, hr, predict_id, topk_mab = main(len(mab_context_id), mab_context, mab_context_id, all_reward_pivot, reward_prod_id, regrets_structure_w, hr_structure_w)
# Out:
# user features: (2602, 20), reward targets: (2602, 1023)
# -----
# aenn
# -----
# vaenn
# -----
# aebnn
# -----
# vaebnn
# -----
# UCB1
# Correct 14
# -----
# LinUCB
# Correct 78
# -----
# Exp3
# Correct 12
# -----
# NeuralUCB
# 100% (2602 of 2602) |####################| Elapsed Time: 0:51:46 Time:  0:51:46
# -----
# random
# Correct 12
# aenn's regret: 0.9723
# vaenn's regret: 0.9643
# aebnn's regret: 0.9985
# vaebnn's regret: 0.9958
# UCB1's regret: [0.9946]
# LinUCB's regret: [0.97]
# Exp3's regret: [0.9954]
# NeuralUCB's regret: 0.9946
# random's regret: [0.9954]
# aenn's hit ratio: 21.68 %
# vaenn's hit ratio: 18.04 %
# aebnn's hit ratio: 3.38 %
# vaebnn's hit ratio: 4.75 %
# UCB1's hit ratio: 9.71 %
# LinUCB's hit ratio: 16.31 %
# Exp3's hit ratio: 42.65 %
# NeuralUCB's hit ratio: 0.04 %

# %%
mab_context = np.load('data/mab_context_new.npy')
mab_context, mab_context_id, _ = preprocess.trim_cust_for_context_sort(mab_context, cust_id, reward_cust_id)
regret, hr, predict_id, topk_mab = main(len(mab_context_id), mab_context, mab_context_id, all_reward_pivot, reward_prod_id, regrets_structure_w, hr_structure_w)
# Out:
# user features: (2602, 75), reward targets: (2602, 1023)
# -----
# aenn
# -----
# vaenn
# -----
# aebnn
# -----
# vaebnn
# -----
# UCB1
# Correct 14
# -----
# LinUCB
# Correct 13
# -----
# Exp3
# Correct 13
# -----
# NeuralUCB
